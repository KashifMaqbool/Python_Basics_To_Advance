# %% [markdown]
# # Operating system Module

# %% [markdown]
# ## 1. Slides

# %% [markdown]
# ![image.png](attachment:016ce212-58a9-4186-9351-18c6996e47f1.png)
# ![image.png](attachment:725da770-67a9-426c-b37d-3b0ae40ce181.png)
# ![image.png](attachment:55e13663-a52e-4a9b-b6c5-492285f404b8.png)

# %% [markdown]
# ## 2. Methods

# %%
import os

# %% [markdown]
# ### 2.1 Getting your working directory

# %%
os.getcwd()
# Out:
# '/Users/kashifmaqbool/Python for AI/5_Python_Beta_Part2'

# %% [markdown]
# ### 2.2 Getting list of files inside the directory

# %%
# For your current directory
os.listdir()
# Out:
# ['.DS_Store',
#  '1_Datetime_Module.ipynb',
#  '2_Operating_System_Module.ipynb',
#  '.ipynb_checkpoints']

# %%
# For Path provided directory
os.listdir('/Users/kashifmaqbool/Python for AI/4_Python_Beta_Part1')
# Out:
# ['.DS_Store',
#  '1.2_temperature.csv',
#  '2_Python_Beta_Part1_OOP.ipynb',
#  '1_Python_Beta_Part1_fundamentals.ipynb',
#  '3_Python_best_practices.ipynb',
#  '1.1_read_write.txt',
#  '.ipynb_checkpoints']

# %% [markdown]
# ### 2.3 Changes current directory to path

# %%
os.chdir("/Users/kashifmaqbool/Python for AI/4_Python_Beta_Part1")

# Checking changed directory path
os.getcwd()
# Out:
# '/Users/kashifmaqbool/Python for AI/4_Python_Beta_Part1'

# %%
# Again changing to current path
os.chdir("/Users/kashifmaqbool/Python for AI/5_Python_Beta_Part2")
print(os.getcwd())
print(os.listdir())
# Out:
# /Users/kashifmaqbool/Python for AI/5_Python_Beta_Part2
# ['.DS_Store', '1_Datetime_Module.ipynb', '2_Operating_System_Module.ipynb', '.ipynb_checkpoints']

# %% [markdown]
# ### 2.4 Making or creating a new directory

# %%
print(os.listdir())  # Checking folders inside directory before creating a new forlder

os.mkdir('/Users/kashifmaqbool/Python for AI/5_Python_Beta_Part2/Test_Folder')

print(os.listdir())  # Folders after creating a folder
# Out:
# ['.DS_Store', '1_Datetime_Module.ipynb', '2_Operating_System_Module.ipynb', '.ipynb_checkpoints']
# ['Test_Folder', '.DS_Store', '1_Datetime_Module.ipynb', '2_Operating_System_Module.ipynb', '.ipynb_checkpoints']

# %% [markdown]
# ### 2.5 Deleting folder from a directory

# %%
os.removedirs('Test_Folder')

# %%
# Now the current directory will not have the Test_Folder which we have created above
os.listdir()
# Out:
# ['.DS_Store',
#  '1_Datetime_Module.ipynb',
#  '2_Operating_System_Module.ipynb',
#  '.ipynb_checkpoints']

# %% [markdown]
# ### 2.6 Checking provided path exists or not

# %%
os.path.exists('/Users/kashifmaqbool/Python for AI/5_Python_Beta_Part2/Test_Folder')  # False because we have deleted the Test_Folder
# Out:
# False

# %%
os.path.exists('/Users/kashifmaqbool/Python for AI/5_Python_Beta_Part2')  # True because this path or directory exists
# Out:
# True

# %% [markdown]
# ### 2.7 Checking whether file exists in the directory or not

# %%
os.path.isfile('/Users/kashifmaqbool/Python for AI/5_Python_Beta_Part2/Test_Folder') # False because we have deleted the Test_Folder
# Out:
# False

# %% [markdown]
# ### 2.8 Checking whether path exist or not

# %%
os.path.isdir('/Users/kashifmaqbool/Python for AI/5_Python_Beta_Part2')  # True because this path exists or it is current directory
# Out:
# True
